# %%
# AWS Automation Projects with boto3
# Notebook-style script (.ipynb compatible structure can be copied into Jupyter cells)
# Requisitos:
# pip install boto3
# AWS CLI configurado con credenciales válidas

# ============================================================
# CELDA 1 - IMPORTS Y CONFIGURACIÓN GENERAL
# ============================================================
import boto3
import os
import json
from datetime import datetime, timezone, timedelta
from pathlib import Path

REGION = 'us-west-2'  # Cambia tu región
BUCKET_NAME = 'bucket-ppractitioner-1775719339'
LOCAL_FILE = 'archivo_local.txt'
DOWNLOAD_PATH = 'archivo_descargado.txt'
BACKUP_FOLDER = './mi_carpeta_local'
IAM_POLICY_ARN = 'arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess'

s3 = boto3.client('s3', region_name=REGION)
ec2 = boto3.client('ec2', region_name=REGION)
cloudwatch = boto3.client('cloudwatch', region_name=REGION)
iam = boto3.client('iam')
lambda_client = boto3.client('lambda', region_name=REGION)
